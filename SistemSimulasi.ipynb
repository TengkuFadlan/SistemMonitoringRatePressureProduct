# %% [markdown]
# # 1. Training

# %% [markdown]
# ## 1.1 Preprocessing

# %%
import numpy as np
import pandas as pd
from scipy.signal import butter, filtfilt, iirnotch, lfilter, medfilt, find_peaks
import joblib

# ── 1) LOAD YOUR DATA
df = pd.read_csv('df.csv')

# ── 2) SETUP FILTERS & PARAMETERS
fs = 125 # Hz sampling rate

# (a) Baseline-wander high-pass
def highpass_filter(x, cutoff=0.5, fs=fs, order=2):
    b, a = butter(order, cutoff/(0.5*fs), btype='high')
    return filtfilt(b, a, x)
    
# (b) Notch at mains frequency
def notch_filter(x, fs=fs, f0=50.0, Q=30.0):
    b, a = iirnotch(f0/(fs/2), Q)
    return filtfilt(b, a, x)
    
# (c) Pan–Tompkins low-pass: H_lp(z) = (1 - z^-6)^2 / (1 - z^-1)^2
b_lp = np.zeros(13)
b_lp[0] = 1
b_lp[6] = -2
b_lp[12] = 1
# denominator: 1 - 2z^-1 + z^-2
a_lp = np.array([1, -2, 1])

# (d) Pan–Tompkins high-pass: H_hp(z) = z^-16 - (1 - z^-32)/(1 - z^-1)
# Expand numerator: -1 for z^0..z^31, +1 at z^16
b_hp = -np.ones(32)
b_hp[16] += 1
# denominator: 1 - z^-1
a_hp = np.array([1, -1])

# (e) Derivative (5-point) kernel: y[n] = (1/8)[2x(n) + x(n-1) - x(n-3) - 2x(n-4)]
deriv_kernel = np.array([2, 1, 0, -1, -2]) / 8.0

# (f) Moving-window integration (150 ms)
mwi_win = int(0.150 * fs)
mwi_kernel = np.ones(mwi_win) / mwi_win

# ── 3) ECG PREPROCESSING
ecg_raw = df['ECG'].values

# 1) high-pass → notch
ecg_hp = highpass_filter(ecg_raw)
ecg_notch = notch_filter(ecg_hp)

# 2) compute & save global normalization params
ecg_mean = ecg_notch.mean()
ecg_std = ecg_notch.std()
ecg_stats = {
    'mean': ecg_mean,
    'std': ecg_std,
    'min': ecg_notch.min(),
    'max': ecg_notch.max()
}
joblib.dump(ecg_stats, 'params.pkl')

# 3) z-score normalize
ecg_norm = (ecg_notch - ecg_mean) / ecg_std

# 4) Pan–Tompkins filters
# a) low-pass
y_lp = lfilter(b_lp, a_lp, ecg_norm)
# b) high-pass
y_hp = lfilter(b_hp, a_hp, y_lp)
# c) derivative
y_der = np.convolve(y_hp, deriv_kernel, mode='same')
# d) squaring
y_sq = y_der ** 2
# e) moving-window integration
y_mwi = np.convolve(y_sq, mwi_kernel, mode='same')

# 5) store envelope (for QRS detection / features)
df['ecg_preproc'] = y_mwi

# ── 4) EPOCH-LEVEL ABP EXTRACTION
epoch_sec = 20
samples_per_epoch = fs * epoch_sec
# median filter kernel for ABP (0.2 s)
kernel = int(0.2 * fs)
if kernel % 2 == 0:
    kernel += 1
    
epoch_indices = []
epoch_sbp, epoch_dbp = [], []
num_epochs = len(df) // samples_per_epoch

for i in range(num_epochs):
    start = i * samples_per_epoch
    end = start + samples_per_epoch
    epoch_indices.append((start, end))
    
    abp_seg = df['ABP'].iloc[start:end].values
    abp_smooth = medfilt(abp_seg, kernel_size=kernel)
    
    # systolic peaks
    locs_s, _ = find_peaks(abp_smooth, distance=int(0.25 * fs))
    vals_s = abp_seg[locs_s]
    
    # diastolic troughs between peaks
    locs_d = []
    for j in range(len(locs_s) - 1):
        seg = abp_smooth[locs_s[j]:locs_s[j+1]]
        if seg.size:
            trough = np.argmin(seg)
            locs_d.append(locs_s[j] + trough)
    vals_d = abp_seg[locs_d]
    
    # median of top-beats
    sbp = np.median(np.sort(vals_s)[-epoch_sec:]) if vals_s.size else np.nan
    dbp = np.median(np.sort(vals_d)[-epoch_sec:]) if vals_d.size else np.nan
    
    epoch_sbp.append(sbp)
    epoch_dbp.append(dbp)
    
# assemble results
epoch_df = pd.DataFrame({'systolic': epoch_sbp, 'diastolic': epoch_dbp})
epoch_df.tail()
# Out:
#      systolic  diastolic
# 857      88.0       53.6
# 858      88.4       54.4
# 859      86.4       53.6
# 860      88.0       55.2
# 861      88.4       54.8

# %% [markdown]
# ## 2.2 Definisi Fungsi

# %%
def shape_factor(signal):
    """
    Compute the Shape Factor of a 1D signal array.
    SF = X_rms / ( (1/n) * sum of sqrt(|x_i|) )
    """
    n = len(signal)
    xrms = np.sqrt(np.mean(signal**2))
    # compute mean of sqrt(|x_i|)
    mean_sqrt_abs = np.mean(np.sqrt(np.abs(signal)))
    sf = xrms / mean_sqrt_abs
    return sf

def svd_feature(signal_matrix):
    """
    Compute a feature from the SVD of a 2D 'signal_matrix'.
    For instance, we might return the largest singular value (sigma_1).
    """
    # Perform SVD: X = U * S * V^T
    U, S, Vt = np.linalg.svd(signal_matrix, full_matrices=False)
    # Example: return the largest singular value
    return S[0] # sigma_1

def mean_feature(signal):
    """
    Compute the mean of a 1D signal array.
    Formula:
    mean = (1 / n) * sum(x_i), for i in [1..n]
    """
    return np.mean(signal)

def rms_feature(signal):
    """
    Compute the RMS (root mean square) of a 1D signal array.
    Formula:
    RMS = sqrt( (1/n) * sum(x_i^2) ), for i in [1..n]
    """
    return np.sqrt(np.mean(signal**2))

def average_energy(signal):
    """
    Compute the average energy of a 1D signal array.
    Formula:
    Energy = (1/n) * sum(x_i^2), for i in [1..n]
    Note: This is equivalent to RMS^2.
    """
    return np.mean(signal**2)

def skewness(x):
    """
    Computes the sample skewness of x.
    Formula (for sample skewness):
    skew = [ Σ (x_i - mean_x)^3 ] / [ (n-1) * (std_x^3) ]
    """
    n = len(x)
    mean_x = np.mean(x)
    std_x = np.std(x, ddof=1) # sample standard deviation
    if std_x == 0:
        return 0.0
    skew = np.sum((x - mean_x)**3) / ((n - 1) * (std_x**3))
    return skew

def coefficient_of_variation(x):
    """
    Computes the Coefficient of Variation (CV) of x, in percentage.
    Formula:
    CV = (std_x / mean_x) * 100
    """
    mean_x = np.mean(x)
    std_x = np.std(x, ddof=1)
    if mean_x == 0:
        return 0.0
    return (std_x / mean_x) * 100

def standard_deviation(signal):
    """
    Computes the sample standard deviation of a 1D signal.
    """
    return np.std(signal, ddof=1)

def hjorth_activity(signal):
    """
    Hjorth Activity is the variance of the signal.
    """
    return np.var(signal, ddof=1)

def hjorth_mobility(signal):
    """
    Hjorth Mobility = sqrt( Var(d/dt(signal)) / Var(signal) )
    """
    activity = hjorth_activity(signal)
    if activity == 0:
        return 0.0
    first_deriv = np.diff(signal)
    return np.sqrt(np.var(first_deriv, ddof=1) / activity)

def hjorth_complexity(signal):
    """
    Hjorth Complexity = (Mobility of first derivative) / (Mobility of original signal).
    Equivalent to:
    sqrt(
    [Var(d^2/dt^2(signal)) / Var(d/dt(signal))] /
    [Var(d/dt(signal)) / Var(signal)]
    )
    """
    activity = hjorth_activity(signal)
    mob = hjorth_mobility(signal)
    if mob == 0:
        return 0.0
        
    first_deriv = np.diff(signal)
    second_deriv = np.diff(first_deriv)
    var_first = np.var(first_deriv, ddof=1)
    var_second = np.var(second_deriv, ddof=1)
    
    if var_first == 0:
        return 0.0
        
    return np.sqrt((var_second / var_first) / (var_first / activity))

def central_moment_10(x):
    """
    Computes the 10th central moment of x.
    Formula (general nth central moment):
    CM_n = (1/n) * Σ (x_i - mean_x)^n
    Here we use n=10 by default.
    """
    mean_x = np.mean(x)
    return np.mean((x - mean_x)**10)

# %% [markdown]
# ## 1.3 Ekstraksi Fitur

# %%
# 1. Create lists to store features for each epoch
ecg_means = []
ecg_rms_vals = []
ecg_energy_vals = []
ecg_sf_vals = []
ecg_svd_vals = []

# -- New features --
ecg_skewness_vals = []
ecg_cv_vals = []
ecg_activity_vals = []
ecg_mobility_vals = []
ecg_cm10_vals = []
ecg_complexity_vals = []
ecg_std_vals = []

# 2. Loop over each epoch, extract features
for (start, end) in epoch_indices:
    ecg_epoch = df['ecg_preproc'].iloc[start:end].values
    # Existing features
    val_mean = mean_feature(ecg_epoch)
    val_rms = rms_feature(ecg_epoch)
    val_energy = average_energy(ecg_epoch)
    val_sf = shape_factor(ecg_epoch)
    ecg_2d = ecg_epoch.reshape(-1, 1)
    val_svd = svd_feature(ecg_2d)
    # New features
    val_skew = skewness(ecg_epoch)
    val_cv = coefficient_of_variation(ecg_epoch)
    val_activity = hjorth_activity(ecg_epoch)
    val_mobility = hjorth_mobility(ecg_epoch)
    val_cm10 = central_moment_10(ecg_epoch)
    val_complexity = hjorth_complexity(ecg_epoch)
    val_std = standard_deviation(ecg_epoch)
    # Append to lists
    ecg_means.append(val_mean)
    ecg_rms_vals.append(val_rms)
    ecg_energy_vals.append(val_energy)
    ecg_sf_vals.append(val_sf)
    ecg_svd_vals.append(val_svd)
    ecg_skewness_vals.append(val_skew)
    ecg_cv_vals.append(val_cv)
    ecg_activity_vals.append(val_activity)
    ecg_mobility_vals.append(val_mobility)
    ecg_cm10_vals.append(val_cm10)
    ecg_complexity_vals.append(val_complexity)
    ecg_std_vals.append(val_std)

# 3. Rebuild epoch_df to include epoch_start, epoch_end, BPs, and new features
epoch_df = pd.DataFrame({
    'systolic': epoch_df['systolic'],
    'diastolic': epoch_df['diastolic'],
    'ecg_mean': ecg_means,
    'ecg_rms': ecg_rms_vals,
    'ecg_energy': ecg_energy_vals,
    'ecg_sf': ecg_sf_vals,
    'ecg_svd': ecg_svd_vals,
    'ecg_skewness': ecg_skewness_vals,
    'ecg_cv': ecg_cv_vals,
    'ecg_activity': ecg_activity_vals,
    'ecg_mobility': ecg_mobility_vals,
    'ecg_cm10': ecg_cm10_vals,
    'ecg_complexity': ecg_complexity_vals,
    'ecg_std': ecg_std_vals
})

epoch_df.tail()
# Out:
#      systolic  diastolic       ecg_mean        ecg_rms    ecg_energy  \
# 857      88.0       53.6  250880.935032  352619.232058  1.243403e+11
# 858      88.4       54.4  262632.211170  374914.319598  1.405607e+11
# 859      86.4       53.6  257045.347286  354410.695904  1.256069e+11
# 860      88.0       55.2  248796.228590  355527.629917  1.263999e+11
# 861      88.4       54.8  256066.077067  364350.011064  1.327509e+11
#
#          ecg_sf       ecg_svd  ecg_skewness      ecg_cv  ecg_activity  \
# 857  828.317899  1.763096e+07      0.890283   98.787079  6.142365e+10
# 858  860.889997  1.874572e+07      1.258847  101.894351  7.161371e+10
# 859  816.974536  1.772053e+07      0.712317   94.942784  5.955845e+10
# 860  841.230640  1.777638e+07      1.030698  102.099604  6.452614e+10
# 861  854.995043  1.821750e+07      1.023067  101.241452  6.720798e+10
#
#      ecg_mobility      ecg_cm10  ecg_complexity        ecg_std
# 857      0.127977  1.918923e+57        1.453824  247837.948495
# 858      0.123261  5.373743e+58        1.498820  267607.388129
# 859      0.132557  1.392389e+56        1.417490  244046.008349
# 860      0.127285  3.363253e+57        1.458212  254019.965221
# 861      0.127751  1.370926e+58        1.444072  259245.015244

# %% [markdown]
# ## 1.4 Pelatihan Model

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ----------------------------------
# 1) Define feature & target columns
# ----------------------------------
# Suppose you have these columns in epoch_df (including the ones you want to scale)
feature_columns = [
"ecg_mean", "ecg_sf", "ecg_mobility","ecg_skewness", "ecg_cv", "ecg_complexity", "ecg_cm10"
]

# Targets
target_sbp = "systolic"
target_dbp = "diastolic"

# Bersihkan
epoch_df.dropna(inplace=True)

# ----------------------------------
# 2) Split into X, y
# ----------------------------------
X = epoch_df[feature_columns].copy() # copy so we can safely modify
y_sbp = epoch_df[target_sbp].values
y_dbp = epoch_df[target_dbp].values

# ----------------------------------
# 3) Train-Test Split
# ----------------------------------
X_train, X_test, y_sbp_train, y_sbp_test = train_test_split(X, y_sbp, test_size=0.2, random_state=42)

# For DBP, use the same split indices:
_, _, y_dbp_train, y_dbp_test = train_test_split(
    X, y_dbp, test_size=0.2, random_state=42
)

from sklearn.preprocessing import MinMaxScaler
import joblib

# ─── 4) SCALE FEATURES
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train) # fit on train only
X_test_scaled = scaler.transform(X_test) # same transform on test

# save for live inference
joblib.dump(scaler, 'feat_scaler.pkl')

from sklearn.ensemble import RandomForestRegressor

# Define the hyperparameters
params = {
    'max_depth': None,
    'max_features': 'sqrt',
    'min_samples_split': 2,
    'n_estimators': 500
}

# Train Random Forest Regression for Systolic BP
rf_sbp = RandomForestRegressor(random_state=42)
rf_sbp.fit(X_train_scaled, y_sbp_train)

# Train Random Forest Regression for Diastolic BP
rf_dbp = RandomForestRegressor(random_state=42)
rf_dbp.fit(X_train_scaled, y_dbp_train)

joblib.dump(rf_sbp, "rf2_sbp.pkl") 
joblib.dump(rf_dbp, "rf2_dbp.pkl")

print("Model SBP dan DBP berhasil disimpan!")
# Out:
# Model SBP dan DBP berhasil disimpan!

# %% [markdown]
# # 2. Sistem

# %% [markdown]
# ## 2.1 Inisialisasi Sistem

# %%
import sys
import time
from collections import deque
import warnings
import numpy as np
import pandas as pd
import serial
#from serial import SerialException
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import joblib
#from pyshimmer import ShimmerBluetooth, DEFAULT_BAUDRATE, DataPacket, EChannelType
# ————— SUPPRESS SCALER WARNING —————
warnings.filterwarnings(
    "ignore",
    message="X does not have valid feature names, but MinMaxScaler was fitted with feature names"
)
# ————— CONFIG —————
PORT = 'COM3' # port serial
FS = 125 # sampling rate [Hz]
BUF_SEC = 20 # detik untuk buffer
BUF_SZ = FS * BUF_SEC
V_REF = 2.42 # referensi tegangan [V]
GAIN = 4 # gain amplifier
SENS_MV = V_REF / (GAIN * (2**23 - 1)) * 1000 # mV per ADC count
#CH_ECG = EChannelType.EXG_ADS1292R_1_CH1_24BIT # channel ECG
# ————— LOAD MODELS & SCALERS —————
model_sbp = joblib.load("rf2_sbp.pkl") # trained RF for SBP

model_dbp = joblib.load("rf2_dbp.pkl") # trained RF for DBP
feat_scaler = joblib.load("feat_scaler.pkl")# feature-level scaler
ecg_stats = joblib.load("params.pkl") # global envelope stats (if needed)
# ————— BUFFER & COUNTER —————
buf = deque(maxlen=BUF_SZ)
sample_count = 0
def to_signed24(x):
    return x - 0x1000000 if (x & 0x800000) else x



# SIMULASI
df_sim = pd.read_csv('df.csv')
sim_data = df_sim['ECG'].values # Ambil kolom ECG
sim_idx = 0

# Tambahkan mwi_kernel (di Kode 5 Mas Ilham dipakai tapi belum didefinisikan di snippetmu)
mwi_win = int(0.150 * FS)
mwi_kernel = np.ones(mwi_win) / mwi_win

# Buffer tetap sama
buf = deque(maxlen=BUF_SZ)
sample_count = 0

# %% [markdown]
# ## 2.2 Callback Data Stream

# %%
# GANTI SELURUH KODE 2 DENGAN INI:
def simulate_stream():
    global sample_count, sim_idx
    # Simulasi data datang 1 sampel
    if sim_idx < len(sim_data):
        val = sim_data[sim_idx]
        buf.append(val)
        sample_count += 1
        sim_idx += 1

# %% [markdown]
# ## 2.3 Definisi Fungsi Ekstraksi Fitur

# %%
def mean_feature(x):
    return np.mean(x)
    
def shape_factor(x):
    xrms = np.sqrt(np.mean(x**2))
    msa = np.mean(np.sqrt(np.abs(x)))
    return xrms/msa if msa else 0.0

def mobility(x):
    vs = np.var(x, ddof=1)
    vd = np.var(np.diff(x), ddof=1) if x.size > 1 else 0.0
    return np.sqrt(vd/vs) if vs else 0.0
    
def complexity(x):
    vs = np.var(x, ddof=1)
    d1 = np.diff(x)
    v1 = np.var(d1, ddof=1) if d1.size > 1 else 0.0
    d2 = np.diff(d1)
    v2 = np.var(d2, ddof=1) if d2.size > 1 else 0.0
    return np.sqrt((v2/v1)/(v1/vs)) if vs and v1 else 0.0
    
def skewness(x):
    n = x.size
    mu = np.mean(x)
    s = np.std(x, ddof=1)
    return np.sum((x-mu)**3)/((n-1)*s**3) if s and n > 1 else 0.0
    
def coef_var(x):
    mu = np.mean(x)
    s = np.std(x, ddof=1)
    return (s/mu)*100 if mu else 0.0

def cm10(x):
    mu = np.mean(x)
    return np.mean((x-mu)**10)

# %% [markdown]
# ## 2.4 Visualisasi dan Tabel

# %%
# ————— PLOT SETUP —————
t = np.linspace(-BUF_SEC, 0, BUF_SZ)
fig, ax = plt.subplots(figsize=(12, 4))
fig.subplots_adjust(bottom=0.25)

line_norm, = ax.plot(t, np.zeros(BUF_SZ), lw=1, label="Normalized ECG")
ax.set_title("Live ECG (0–1) with BP Prediction")
ax.set_xlabel("Time (s)")
ax.set_ylabel("Normalized Amplitude (0–1)")
ax.set_xlim(-BUF_SEC, 0)
ax.set_ylim(0, 1)
ax.legend(loc="upper right")
ax.grid(True)

# ————— ADD TABLE UNDER GRAPH —————
table = ax.table(
    cellText=[["--", "--"]],
    colLabels=["SBP", "DBP"],
    cellLoc="center",
    loc="bottom",
    bbox=[0, -0.3, 1, 0.2]
)

# %% [markdown]
# ## 2.5 Loop Utama dan Prediksi

# %%
# --- SIMULASI MODE PRINT (VERSI BERSIH) ---
print(f"Memulai simulasi... Mengolah data: {len(sim_data)} sampel.")
print("-" * 50)

try:
    # Reset index simulasi
    sim_idx = 0
    sample_count = 0
    buf.clear()

    while sim_idx < len(sim_data):
        # 1. Simulasi data masuk (misal 1 detik data setiap iterasi)
        for _ in range(FS): 
            simulate_stream()
        
        # 2. Syarat Buffer 20 Detik [cite: 524]
        if sample_count >= BUF_SZ:
            # --- PREPROCESSING & ENVELOPE ---
            raw = np.array(buf)
            mn_r, mx_r = raw.min(), raw.max()
            norm = (raw - mn_r)/(mx_r - mn_r) if mx_r > mn_r else np.zeros_like(raw)
            
            # Envelope via MWI [cite: 463, 1046]
            env = np.convolve(norm**2, mwi_kernel, mode="same")
            
            # --- FEATURE EXTRACTION (7 Fitur) [cite: 120] ---
            feats = np.array([
                mean_feature(env), shape_factor(env), mobility(env),
                skewness(env), coef_var(env), complexity(env), cm10(env)
            ]).reshape(1, -1)
            
            # --- SCALE & PREDICT [cite: 1047] ---
            cols = (feat_scaler.feature_names_in_ if hasattr(feat_scaler, "feature_names_in_") else [f"f{i}" for i in range(feats.shape[1])])
            feats_df = pd.DataFrame(feats, columns=cols)
            feats_scaled = feat_scaler.transform(feats_df)
            
            sbp = model_sbp.predict(feats_scaled)[0]
            dbp = model_dbp.predict(feats_scaled)[0]

            # 1. Deteksi Puncak R menggunakan hasil Pan-Tompkins (env/y_mwi)
            peaks, _ = find_peaks(env, distance=int(0.6 * FS), height=np.mean(env))

            # 2. Hitung Heart Rate (HR)
            num_beats = len(peaks)
            hr = (num_beats / BUF_SEC) * 60

            # 3. Hitung Rate Pressure Product (RPP) untuk Skripsimu
            # RPP = HR * SBP
            rpp = hr * sbp

            print(f"Detik ke-{sim_idx/FS:5.1f} | SBP: {sbp:5.1f} | HR: {hr:5.1f} | RPP: {rpp:7.1f}")
            
        # Atur jeda simulasi (0.1s agar terasa live)
        time.sleep(0.1)

except KeyboardInterrupt:
    print("\nSimulasi dihentikan.")
finally:
    print("-" * 50)
    print("Simulasi selesai.")
# Out:
# Memulai simulasi... Mengolah data: 2155174 sampel.
# --------------------------------------------------
# Detik ke- 20.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke- 21.0 | SBP: 111.2 | HR:  72.0 | RPP:  8003.5
# Detik ke- 22.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke- 23.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke- 24.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke- 25.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 26.0 | SBP: 111.5 | HR:  72.0 | RPP:  8026.6
# Detik ke- 27.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke- 28.0 | SBP: 112.4 | HR:  75.0 | RPP:  8430.0
# Detik ke- 29.0 | SBP: 112.4 | HR:  72.0 | RPP:  8091.4
# Detik ke- 30.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke- 31.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 32.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke- 33.0 | SBP: 112.3 | HR:  75.0 | RPP:  8424.3
# Detik ke- 34.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 35.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 36.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 37.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 38.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke- 39.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke- 40.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 41.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke- 42.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke- 43.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 44.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke- 45.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke- 46.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.2
# Detik ke- 47.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 48.0 | SBP: 112.4 | HR:  72.0 | RPP:  8091.4
# Detik ke- 49.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 50.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 51.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.2
# Detik ke- 52.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 53.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 54.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke- 55.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 56.0 | SBP: 113.1 | HR:  72.0 | RPP:  8142.0
# Detik ke- 57.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke- 58.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 59.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke- 60.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 61.0 | SBP: 113.1 | HR:  72.0 | RPP:  8142.0
# Detik ke- 62.0 | SBP: 112.4 | HR:  72.0 | RPP:  8091.4
# Detik ke- 63.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke- 64.0 | SBP: 111.5 | HR:  72.0 | RPP:  8026.6
# Detik ke- 65.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 66.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 67.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 68.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke- 69.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 70.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 71.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 72.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke- 73.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke- 74.0 | SBP: 113.1 | HR:  75.0 | RPP:  8481.3
# Detik ke- 75.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 76.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke- 77.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke- 78.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke- 79.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke- 80.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke- 81.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke- 82.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke- 83.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke- 84.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke- 85.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 86.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke- 87.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke- 88.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 89.0 | SBP: 113.2 | HR:  75.0 | RPP:  8488.5
# Detik ke- 90.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke- 91.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 92.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 93.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke- 94.0 | SBP: 113.1 | HR:  75.0 | RPP:  8484.3
# Detik ke- 95.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 96.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 97.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke- 98.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke- 99.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-100.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-101.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-102.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-103.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-104.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-105.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-106.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-107.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-108.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-109.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-110.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-111.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-112.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-113.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-114.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-115.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-116.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-117.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-118.0 | SBP: 113.7 | HR:  72.0 | RPP:  8182.9
# Detik ke-119.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.4
# Detik ke-120.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.5
# Detik ke-121.0 | SBP: 112.7 | HR:  72.0 | RPP:  8117.6
# Detik ke-122.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.2
# Detik ke-123.0 | SBP: 113.6 | HR:  72.0 | RPP:  8177.8
# Detik ke-124.0 | SBP: 113.8 | HR:  75.0 | RPP:  8533.8
# Detik ke-125.0 | SBP: 113.6 | HR:  72.0 | RPP:  8177.8
# Detik ke-126.0 | SBP: 113.7 | HR:  72.0 | RPP:  8182.9
# Detik ke-127.0 | SBP: 113.7 | HR:  72.0 | RPP:  8182.9
# Detik ke-128.0 | SBP: 113.7 | HR:  72.0 | RPP:  8182.9
# Detik ke-129.0 | SBP: 113.7 | HR:  75.0 | RPP:  8523.9
# Detik ke-130.0 | SBP: 113.7 | HR:  72.0 | RPP:  8182.9
# Detik ke-131.0 | SBP: 113.7 | HR:  72.0 | RPP:  8182.9
# Detik ke-132.0 | SBP: 113.8 | HR:  72.0 | RPP:  8192.4
# Detik ke-133.0 | SBP: 113.4 | HR:  72.0 | RPP:  8167.1
# Detik ke-134.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.4
# Detik ke-135.0 | SBP: 112.7 | HR:  72.0 | RPP:  8117.6
# Detik ke-136.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.2
# Detik ke-137.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.5
# Detik ke-138.0 | SBP: 113.8 | HR:  72.0 | RPP:  8191.6
# Detik ke-139.0 | SBP: 113.2 | HR:  75.0 | RPP:  8488.5
# Detik ke-140.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-141.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-142.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-143.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-144.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke-145.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.2
# Detik ke-146.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-147.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-148.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-149.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke-150.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-151.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-152.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-153.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-154.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-155.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-156.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-157.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-158.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-159.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-160.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-161.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-162.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-163.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-164.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-165.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-166.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-167.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-168.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-169.0 | SBP: 113.7 | HR:  75.0 | RPP:  8525.1
# Detik ke-170.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-171.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-172.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-173.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.2
# Detik ke-174.0 | SBP: 112.6 | HR:  75.0 | RPP:  8443.8
# Detik ke-175.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-176.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-177.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.2
# Detik ke-178.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-179.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-180.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-181.0 | SBP: 113.4 | HR:  72.0 | RPP:  8162.2
# Detik ke-182.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-183.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-184.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke-185.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-186.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-187.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-188.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-189.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke-190.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-191.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-192.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-193.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-194.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-195.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-196.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-197.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-198.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-199.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-200.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-201.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-202.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-203.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-204.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-205.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-206.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-207.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-208.0 | SBP: 109.9 | HR:  75.0 | RPP:  8238.9
# Detik ke-209.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-210.0 | SBP: 109.9 | HR:  72.0 | RPP:  7909.3
# Detik ke-211.0 | SBP: 109.8 | HR:  72.0 | RPP:  7906.8
# Detik ke-212.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-213.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-214.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-215.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-216.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-217.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-218.0 | SBP: 111.3 | HR:  72.0 | RPP:  8013.0
# Detik ke-219.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-220.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-221.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-222.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-223.0 | SBP: 111.2 | HR:  72.0 | RPP:  8003.5
# Detik ke-224.0 | SBP: 110.7 | HR:  72.0 | RPP:  7970.1
# Detik ke-225.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke-226.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-227.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-228.0 | SBP: 111.0 | HR:  72.0 | RPP:  7994.9
# Detik ke-229.0 | SBP: 111.3 | HR:  72.0 | RPP:  8012.7
# Detik ke-230.0 | SBP: 111.2 | HR:  72.0 | RPP:  8003.5
# Detik ke-231.0 | SBP: 111.2 | HR:  72.0 | RPP:  8003.5
# Detik ke-232.0 | SBP: 111.0 | HR:  72.0 | RPP:  7994.9
# Detik ke-233.0 | SBP: 111.2 | HR:  72.0 | RPP:  8003.5
# Detik ke-234.0 | SBP: 111.3 | HR:  75.0 | RPP:  8346.6
# Detik ke-235.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke-236.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-237.0 | SBP: 112.3 | HR:  72.0 | RPP:  8089.1
# Detik ke-238.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-239.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-240.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-241.0 | SBP: 112.4 | HR:  72.0 | RPP:  8091.4
# Detik ke-242.0 | SBP: 111.3 | HR:  72.0 | RPP:  8013.0
# Detik ke-243.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-244.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-245.0 | SBP: 112.3 | HR:  72.0 | RPP:  8089.1
# Detik ke-246.0 | SBP: 111.5 | HR:  72.0 | RPP:  8026.6
# Detik ke-247.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke-248.0 | SBP: 112.4 | HR:  72.0 | RPP:  8091.4
# Detik ke-249.0 | SBP: 113.2 | HR:  75.0 | RPP:  8488.5
# Detik ke-250.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-251.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-252.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-253.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-254.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke-255.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-256.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-257.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-258.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke-259.0 | SBP: 113.2 | HR:  75.0 | RPP:  8488.5
# Detik ke-260.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke-261.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-262.0 | SBP: 111.6 | HR:  72.0 | RPP:  8037.2
# Detik ke-263.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-264.0 | SBP: 112.2 | HR:  75.0 | RPP:  8416.8
# Detik ke-265.0 | SBP: 112.3 | HR:  72.0 | RPP:  8089.1
# Detik ke-266.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-267.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke-268.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-269.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke-270.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-271.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-272.0 | SBP: 113.1 | HR:  72.0 | RPP:  8142.0
# Detik ke-273.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-274.0 | SBP: 112.4 | HR:  75.0 | RPP:  8430.0
# Detik ke-275.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-276.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-277.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-278.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-279.0 | SBP: 112.4 | HR:  75.0 | RPP:  8430.0
# Detik ke-280.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-281.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-282.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-283.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-284.0 | SBP: 113.1 | HR:  75.0 | RPP:  8484.3
# Detik ke-285.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-286.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-287.0 | SBP: 113.1 | HR:  72.0 | RPP:  8142.0
# Detik ke-288.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-289.0 | SBP: 111.6 | HR:  72.0 | RPP:  8037.2
# Detik ke-290.0 | SBP: 111.6 | HR:  72.0 | RPP:  8037.2
# Detik ke-291.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-292.0 | SBP: 111.6 | HR:  72.0 | RPP:  8037.2
# Detik ke-293.0 | SBP: 112.2 | HR:  72.0 | RPP:  8080.1
# Detik ke-294.0 | SBP: 111.3 | HR:  72.0 | RPP:  8012.7
# Detik ke-295.0 | SBP: 111.4 | HR:  72.0 | RPP:  8018.8
# Detik ke-296.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-297.0 | SBP: 111.5 | HR:  72.0 | RPP:  8026.6
# Detik ke-298.0 | SBP: 111.3 | HR:  72.0 | RPP:  8013.0
# Detik ke-299.0 | SBP: 111.3 | HR:  72.0 | RPP:  8013.0
# Detik ke-300.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-301.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-302.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke-303.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-304.0 | SBP: 111.4 | HR:  72.0 | RPP:  8018.8
# Detik ke-305.0 | SBP: 110.7 | HR:  69.0 | RPP:  7638.0
# Detik ke-306.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-307.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-308.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke-309.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-310.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-311.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-312.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-313.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-314.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-315.0 | SBP: 112.4 | HR:  72.0 | RPP:  8092.8
# Detik ke-316.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-317.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-318.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-319.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-320.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-321.0 | SBP: 112.3 | HR:  69.0 | RPP:  7752.0
# Detik ke-322.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-323.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-324.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-325.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-326.0 | SBP: 112.4 | HR:  72.0 | RPP:  8091.4
# Detik ke-327.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-328.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-329.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-330.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-331.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-332.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-333.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-334.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-335.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-336.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-337.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-338.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-339.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-340.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-341.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-342.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-343.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-344.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-345.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-346.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-347.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-348.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-349.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-350.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-351.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-352.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-353.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-354.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke-355.0 | SBP: 112.9 | HR:  72.0 | RPP:  8128.8
# Detik ke-356.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-357.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-358.0 | SBP: 113.4 | HR:  75.0 | RPP:  8507.1
# Detik ke-359.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke-360.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-361.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-362.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-363.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-364.0 | SBP: 113.5 | HR:  75.0 | RPP:  8509.5
# Detik ke-365.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-366.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-367.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-368.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-369.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-370.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-371.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-372.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-373.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-374.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-375.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-376.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-377.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-378.0 | SBP: 112.3 | HR:  72.0 | RPP:  8088.2
# Detik ke-379.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-380.0 | SBP: 112.0 | HR:  69.0 | RPP:  7730.2
# Detik ke-381.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-382.0 | SBP: 112.6 | HR:  69.0 | RPP:  7766.9
# Detik ke-383.0 | SBP: 112.7 | HR:  69.0 | RPP:  7779.3
# Detik ke-384.0 | SBP: 112.7 | HR:  69.0 | RPP:  7779.3
# Detik ke-385.0 | SBP: 112.9 | HR:  69.0 | RPP:  7789.5
# Detik ke-386.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-387.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-388.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-389.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-390.0 | SBP: 112.6 | HR:  69.0 | RPP:  7766.9
# Detik ke-391.0 | SBP: 112.6 | HR:  69.0 | RPP:  7766.9
# Detik ke-392.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-393.0 | SBP: 112.6 | HR:  69.0 | RPP:  7766.9
# Detik ke-394.0 | SBP: 112.3 | HR:  69.0 | RPP:  7751.2
# Detik ke-395.0 | SBP: 111.9 | HR:  69.0 | RPP:  7718.1
# Detik ke-396.0 | SBP: 112.0 | HR:  69.0 | RPP:  7730.2
# Detik ke-397.0 | SBP: 112.0 | HR:  69.0 | RPP:  7726.9
# Detik ke-398.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-399.0 | SBP: 112.2 | HR:  66.0 | RPP:  7406.8
# Detik ke-400.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-401.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-402.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-403.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-404.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-405.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-406.0 | SBP: 111.0 | HR:  66.0 | RPP:  7328.6
# Detik ke-407.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-408.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-409.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-410.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-411.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-412.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-413.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-414.0 | SBP: 112.2 | HR:  66.0 | RPP:  7406.8
# Detik ke-415.0 | SBP: 113.4 | HR:  66.0 | RPP:  7486.2
# Detik ke-416.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-417.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-418.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-419.0 | SBP: 111.6 | HR:  69.0 | RPP:  7700.4
# Detik ke-420.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-421.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.0
# Detik ke-422.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-423.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-424.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-425.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-426.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-427.0 | SBP: 111.0 | HR:  69.0 | RPP:  7661.8
# Detik ke-428.0 | SBP: 110.9 | HR:  69.0 | RPP:  7649.9
# Detik ke-429.0 | SBP: 110.7 | HR:  66.0 | RPP:  7305.9
# Detik ke-430.0 | SBP: 111.2 | HR:  66.0 | RPP:  7342.1
# Detik ke-431.0 | SBP: 111.6 | HR:  66.0 | RPP:  7363.2
# Detik ke-432.0 | SBP: 111.6 | HR:  69.0 | RPP:  7697.9
# Detik ke-433.0 | SBP: 112.4 | HR:  69.0 | RPP:  7754.2
# Detik ke-434.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-435.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-436.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-437.0 | SBP: 111.2 | HR:  66.0 | RPP:  7342.1
# Detik ke-438.0 | SBP: 111.6 | HR:  66.0 | RPP:  7363.2
# Detik ke-439.0 | SBP: 112.7 | HR:  69.0 | RPP:  7774.1
# Detik ke-440.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-441.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-442.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-443.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-444.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-445.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.3
# Detik ke-446.0 | SBP: 113.1 | HR:  66.0 | RPP:  7466.2
# Detik ke-447.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-448.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-449.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-450.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-451.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-452.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-453.0 | SBP: 113.5 | HR:  66.0 | RPP:  7488.4
# Detik ke-454.0 | SBP: 113.6 | HR:  66.0 | RPP:  7497.3
# Detik ke-455.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-456.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-457.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-458.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-459.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-460.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-461.0 | SBP: 113.5 | HR:  66.0 | RPP:  7488.4
# Detik ke-462.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-463.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-464.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-465.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-466.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-467.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-468.0 | SBP: 113.1 | HR:  66.0 | RPP:  7463.5
# Detik ke-469.0 | SBP: 113.4 | HR:  66.0 | RPP:  7486.2
# Detik ke-470.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-471.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-472.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-473.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-474.0 | SBP: 112.3 | HR:  69.0 | RPP:  7752.0
# Detik ke-475.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-476.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.3
# Detik ke-477.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.9
# Detik ke-478.0 | SBP: 113.5 | HR:  69.0 | RPP:  7832.3
# Detik ke-479.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-480.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-481.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-482.0 | SBP: 112.4 | HR:  69.0 | RPP:  7754.2
# Detik ke-483.0 | SBP: 112.2 | HR:  66.0 | RPP:  7406.8
# Detik ke-484.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-485.0 | SBP: 113.4 | HR:  66.0 | RPP:  7486.2
# Detik ke-486.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-487.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-488.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-489.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-490.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-491.0 | SBP: 112.3 | HR:  66.0 | RPP:  7415.0
# Detik ke-492.0 | SBP: 112.6 | HR:  66.0 | RPP:  7430.5
# Detik ke-493.0 | SBP: 113.5 | HR:  66.0 | RPP:  7488.4
# Detik ke-494.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-495.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-496.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-497.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-498.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-499.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.3
# Detik ke-500.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-501.0 | SBP: 113.1 | HR:  66.0 | RPP:  7466.2
# Detik ke-502.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-503.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-504.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-505.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-506.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-507.0 | SBP: 111.2 | HR:  66.0 | RPP:  7336.6
# Detik ke-508.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-509.0 | SBP: 113.2 | HR:  66.0 | RPP:  7469.9
# Detik ke-510.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-511.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-512.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-513.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-514.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-515.0 | SBP: 110.7 | HR:  66.0 | RPP:  7305.9
# Detik ke-516.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.0
# Detik ke-517.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-518.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-519.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-520.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-521.0 | SBP: 111.4 | HR:  69.0 | RPP:  7684.7
# Detik ke-522.0 | SBP: 110.7 | HR:  69.0 | RPP:  7638.0
# Detik ke-523.0 | SBP: 110.9 | HR:  69.0 | RPP:  7649.9
# Detik ke-524.0 | SBP: 110.8 | HR:  66.0 | RPP:  7311.5
# Detik ke-525.0 | SBP: 111.4 | HR:  66.0 | RPP:  7350.8
# Detik ke-526.0 | SBP: 112.4 | HR:  69.0 | RPP:  7756.2
# Detik ke-527.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-528.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-529.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-530.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-531.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-532.0 | SBP: 111.2 | HR:  66.0 | RPP:  7342.1
# Detik ke-533.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.9
# Detik ke-534.0 | SBP: 113.3 | HR:  69.0 | RPP:  7815.2
# Detik ke-535.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-536.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-537.0 | SBP: 111.5 | HR:  69.0 | RPP:  7692.1
# Detik ke-538.0 | SBP: 111.6 | HR:  69.0 | RPP:  7702.3
# Detik ke-539.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-540.0 | SBP: 112.3 | HR:  66.0 | RPP:  7415.0
# Detik ke-541.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-542.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-543.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-544.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-545.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-546.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-547.0 | SBP: 111.4 | HR:  66.0 | RPP:  7353.7
# Detik ke-548.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-549.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-550.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-551.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-552.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-553.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-554.0 | SBP: 112.4 | HR:  69.0 | RPP:  7754.2
# Detik ke-555.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-556.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-557.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-558.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-559.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-560.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-561.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-562.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-563.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-564.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-565.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-566.0 | SBP: 113.4 | HR:  69.0 | RPP:  7822.1
# Detik ke-567.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-568.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-569.0 | SBP: 112.6 | HR:  66.0 | RPP:  7430.5
# Detik ke-570.0 | SBP: 113.1 | HR:  66.0 | RPP:  7466.2
# Detik ke-571.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-572.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-573.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-574.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-575.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-576.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-577.0 | SBP: 112.2 | HR:  66.0 | RPP:  7406.8
# Detik ke-578.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-579.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-580.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-581.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-582.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-583.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-584.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-585.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-586.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-587.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-588.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-589.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-590.0 | SBP: 111.6 | HR:  69.0 | RPP:  7702.3
# Detik ke-591.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-592.0 | SBP: 111.0 | HR:  66.0 | RPP:  7328.6
# Detik ke-593.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-594.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-595.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-596.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-597.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-598.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-599.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-600.0 | SBP: 111.5 | HR:  66.0 | RPP:  7357.7
# Detik ke-601.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-602.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-603.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-604.0 | SBP: 112.6 | HR:  69.0 | RPP:  7768.3
# Detik ke-605.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-606.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-607.0 | SBP: 111.5 | HR:  66.0 | RPP:  7357.7
# Detik ke-608.0 | SBP: 113.2 | HR:  66.0 | RPP:  7471.7
# Detik ke-609.0 | SBP: 113.5 | HR:  69.0 | RPP:  7832.3
# Detik ke-610.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-611.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-612.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-613.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-614.0 | SBP: 111.5 | HR:  69.0 | RPP:  7692.1
# Detik ke-615.0 | SBP: 111.4 | HR:  66.0 | RPP:  7350.6
# Detik ke-616.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-617.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-618.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-619.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-620.0 | SBP: 111.6 | HR:  69.0 | RPP:  7700.4
# Detik ke-621.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-622.0 | SBP: 111.0 | HR:  66.0 | RPP:  7328.6
# Detik ke-623.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-624.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-625.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-626.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-627.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-628.0 | SBP: 111.2 | HR:  69.0 | RPP:  7670.0
# Detik ke-629.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-630.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.3
# Detik ke-631.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-632.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-633.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-634.0 | SBP: 111.5 | HR:  69.0 | RPP:  7692.1
# Detik ke-635.0 | SBP: 111.5 | HR:  69.0 | RPP:  7692.1
# Detik ke-636.0 | SBP: 111.6 | HR:  69.0 | RPP:  7702.3
# Detik ke-637.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.3
# Detik ke-638.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-639.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-640.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-641.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-642.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-643.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-644.0 | SBP: 112.3 | HR:  66.0 | RPP:  7415.0
# Detik ke-645.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-646.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-647.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-648.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-649.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-650.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-651.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-652.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-653.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-654.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-655.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-656.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-657.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-658.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-659.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-660.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-661.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-662.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-663.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-664.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-665.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-666.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-667.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-668.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-669.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-670.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-671.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-672.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-673.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-674.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-675.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-676.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-677.0 | SBP: 113.4 | HR:  69.0 | RPP:  7822.1
# Detik ke-678.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-679.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-680.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-681.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-682.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-683.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-684.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-685.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-686.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-687.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-688.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-689.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-690.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-691.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-692.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-693.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-694.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-695.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-696.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-697.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-698.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-699.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-700.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-701.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-702.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-703.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-704.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-705.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-706.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-707.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-708.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-709.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-710.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-711.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-712.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-713.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-714.0 | SBP: 113.4 | HR:  66.0 | RPP:  7486.2
# Detik ke-715.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-716.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-717.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-718.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-719.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-720.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-721.0 | SBP: 113.4 | HR:  66.0 | RPP:  7486.2
# Detik ke-722.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-723.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-724.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-725.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-726.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-727.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-728.0 | SBP: 112.3 | HR:  66.0 | RPP:  7413.4
# Detik ke-729.0 | SBP: 113.1 | HR:  66.0 | RPP:  7466.2
# Detik ke-730.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-731.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-732.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-733.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-734.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-735.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-736.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.0
# Detik ke-737.0 | SBP: 112.5 | HR:  66.0 | RPP:  7423.9
# Detik ke-738.0 | SBP: 113.2 | HR:  69.0 | RPP:  7811.4
# Detik ke-739.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-740.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-741.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-742.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-743.0 | SBP: 111.3 | HR:  66.0 | RPP:  7345.0
# Detik ke-744.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.9
# Detik ke-745.0 | SBP: 113.5 | HR:  69.0 | RPP:  7832.3
# Detik ke-746.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-747.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-748.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-749.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-750.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-751.0 | SBP: 111.7 | HR:  66.0 | RPP:  7371.1
# Detik ke-752.0 | SBP: 113.2 | HR:  66.0 | RPP:  7469.9
# Detik ke-753.0 | SBP: 113.5 | HR:  69.0 | RPP:  7832.3
# Detik ke-754.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-755.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-756.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-757.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-758.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-759.0 | SBP: 111.4 | HR:  66.0 | RPP:  7353.7
# Detik ke-760.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-761.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-762.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-763.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-764.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-765.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-766.0 | SBP: 111.6 | HR:  66.0 | RPP:  7367.4
# Detik ke-767.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-768.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-769.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-770.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-771.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-772.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-773.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-774.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-775.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-776.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-777.0 | SBP: 111.6 | HR:  69.0 | RPP:  7700.4
# Detik ke-778.0 | SBP: 112.3 | HR:  69.0 | RPP:  7752.0
# Detik ke-779.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-780.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-781.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-782.0 | SBP: 111.5 | HR:  69.0 | RPP:  7692.1
# Detik ke-783.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-784.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-785.0 | SBP: 111.4 | HR:  69.0 | RPP:  7684.7
# Detik ke-786.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-787.0 | SBP: 111.0 | HR:  69.0 | RPP:  7661.8
# Detik ke-788.0 | SBP: 111.4 | HR:  72.0 | RPP:  8022.2
# Detik ke-789.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-790.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-791.0 | SBP: 111.3 | HR:  69.0 | RPP:  7678.9
# Detik ke-792.0 | SBP: 111.3 | HR:  69.0 | RPP:  7679.1
# Detik ke-793.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-794.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-795.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-796.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-797.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-798.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-799.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-800.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-801.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-802.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-803.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-804.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-805.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-806.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-807.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-808.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-809.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-810.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-811.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-812.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-813.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-814.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-815.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-816.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-817.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-818.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-819.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-820.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-821.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-822.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-823.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-824.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-825.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-826.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-827.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-828.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-829.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-830.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-831.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-832.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-833.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-834.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-835.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-836.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-837.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-838.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-839.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-840.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-841.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-842.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-843.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-844.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-845.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-846.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-847.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-848.0 | SBP: 113.5 | HR:  72.0 | RPP:  8170.8
# Detik ke-849.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-850.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-851.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-852.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-853.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-854.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-855.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-856.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-857.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-858.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-859.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-860.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-861.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-862.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-863.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-864.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-865.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-866.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-867.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-868.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-869.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-870.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-871.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-872.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-873.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-874.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-875.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-876.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-877.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-878.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-879.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-880.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-881.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-882.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-883.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-884.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-885.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-886.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-887.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-888.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-889.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# ...
# Detik ke-1089.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-1090.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1091.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-1092.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1093.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1094.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1095.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-1096.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1097.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1098.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1099.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1100.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1101.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1102.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1103.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1104.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1105.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1106.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1107.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-1108.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1109.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1110.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1111.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1112.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1113.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-1114.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1115.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1116.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1117.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1118.0 | SBP: 113.2 | HR:  72.0 | RPP:  8149.0
# Detik ke-1119.0 | SBP: 113.1 | HR:  72.0 | RPP:  8142.0
# Detik ke-1120.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-1121.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-1122.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1123.0 | SBP: 112.9 | HR:  69.0 | RPP:  7790.1
# Detik ke-1124.0 | SBP: 112.3 | HR:  72.0 | RPP:  8087.3
# Detik ke-1125.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-1126.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1127.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1128.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1129.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1130.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1131.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-1132.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-1133.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1134.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1135.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-1136.0 | SBP: 112.2 | HR:  69.0 | RPP:  7743.5
# Detik ke-1137.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-1138.0 | SBP: 112.2 | HR:  66.0 | RPP:  7406.8
# Detik ke-1139.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1140.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1141.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1142.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1143.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1144.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1145.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1146.0 | SBP: 113.1 | HR:  66.0 | RPP:  7466.2
# Detik ke-1147.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1148.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-1149.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1150.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-1151.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1152.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-1153.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-1154.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1155.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1156.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1157.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1158.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1159.0 | SBP: 112.4 | HR:  69.0 | RPP:  7754.2
# Detik ke-1160.0 | SBP: 112.4 | HR:  66.0 | RPP:  7418.4
# Detik ke-1161.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1162.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1163.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1164.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1165.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1166.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1167.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1168.0 | SBP: 113.5 | HR:  66.0 | RPP:  7488.4
# Detik ke-1169.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1170.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-1171.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1172.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1173.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1174.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1175.0 | SBP: 113.1 | HR:  66.0 | RPP:  7466.2
# Detik ke-1176.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1177.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1178.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1179.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1180.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1181.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1182.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1183.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1184.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-1185.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-1186.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1187.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1188.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1189.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1190.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1191.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1192.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-1193.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1194.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1195.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1196.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1197.0 | SBP: 113.5 | HR:  66.0 | RPP:  7488.4
# Detik ke-1198.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-1199.0 | SBP: 113.6 | HR:  69.0 | RPP:  7838.1
# Detik ke-1200.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1201.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1202.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1203.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1204.0 | SBP: 113.4 | HR:  66.0 | RPP:  7486.2
# Detik ke-1205.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1206.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1207.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1208.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1209.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1210.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1211.0 | SBP: 112.6 | HR:  69.0 | RPP:  7768.3
# Detik ke-1212.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-1213.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1214.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1215.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1216.0 | SBP: 112.6 | HR:  69.0 | RPP:  7768.3
# Detik ke-1217.0 | SBP: 111.4 | HR:  69.0 | RPP:  7688.0
# Detik ke-1218.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-1219.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1220.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1221.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1222.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1223.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1224.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1225.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-1226.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1227.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1228.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1229.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1230.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1231.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1232.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-1233.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1234.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1235.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1236.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1237.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1238.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-1239.0 | SBP: 113.7 | HR:  72.0 | RPP:  8184.1
# Detik ke-1240.0 | SBP: 113.7 | HR:  69.0 | RPP:  7843.1
# Detik ke-1241.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1242.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1243.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1244.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1245.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1246.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1247.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1248.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1249.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1250.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1251.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1252.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1253.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1254.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1255.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1256.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1257.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1258.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-1259.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1260.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1261.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1262.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1263.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-1264.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-1265.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-1266.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1267.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1268.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1269.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1270.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1271.0 | SBP: 113.6 | HR:  72.0 | RPP:  8178.9
# Detik ke-1272.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1273.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1274.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-1275.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1276.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1277.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1278.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1279.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1280.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1281.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1282.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1283.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1284.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1285.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1286.0 | SBP: 113.5 | HR:  69.0 | RPP:  7830.4
# Detik ke-1287.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1288.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1289.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1290.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1291.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1292.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1293.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1294.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1295.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1296.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1297.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1298.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-1299.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1300.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1301.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1302.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1303.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1304.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1305.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1306.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1307.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1308.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1309.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1310.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1311.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1312.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1313.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1314.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1315.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1316.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1317.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1318.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1319.0 | SBP: 112.3 | HR:  69.0 | RPP:  7750.4
# Detik ke-1320.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1321.0 | SBP: 113.4 | HR:  69.0 | RPP:  7822.1
# Detik ke-1322.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1323.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1324.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1325.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1326.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1327.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1328.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1329.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1330.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1331.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1332.0 | SBP: 113.4 | HR:  69.0 | RPP:  7822.1
# Detik ke-1333.0 | SBP: 113.4 | HR:  69.0 | RPP:  7822.1
# Detik ke-1334.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1335.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1336.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1337.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1338.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1339.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1340.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1341.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1342.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1343.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1344.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1345.0 | SBP: 113.2 | HR:  69.0 | RPP:  7809.4
# Detik ke-1346.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1347.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1348.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1349.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1350.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1351.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1352.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1353.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1354.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1355.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1356.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1357.0 | SBP: 113.1 | HR:  69.0 | RPP:  7802.8
# Detik ke-1358.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1359.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1360.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1361.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1362.0 | SBP: 113.1 | HR:  72.0 | RPP:  8144.9
# Detik ke-1363.0 | SBP: 112.3 | HR:  69.0 | RPP:  7752.0
# Detik ke-1364.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1365.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
# Detik ke-1366.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1367.0 | SBP: 113.5 | HR:  72.0 | RPP:  8169.1
# Detik ke-1368.0 | SBP: 113.4 | HR:  72.0 | RPP:  8166.8
# Detik ke-1369.0 | SBP: 112.4 | HR:  69.0 | RPP:  7755.6
# Detik ke-1370.0 | SBP: 113.1 | HR:  69.0 | RPP:  7805.6
# Detik ke-1371.0 | SBP: 113.4 | HR:  69.0 | RPP:  7826.5
# Detik ke-1372.0 | SBP: 113.5 | HR:  69.0 | RPP:  7828.7
#
# Simulasi dihentikan.
# --------------------------------------------------
# Simulasi selesai.
